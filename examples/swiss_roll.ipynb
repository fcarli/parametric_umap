# %%
import sys
sys.path.append('/home/fcarli/WebCellHit/analysis/parametric_umap')

from parametric_umap import ParametricUMAP

from sklearn.datasets import make_swiss_roll
import matplotlib.pyplot as plt

# %%
n_samples = 1000
X, color = make_swiss_roll(n_samples=n_samples, noise=0, random_state=42)

# %%
# Create a 3D plot
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Plot the points
scatter = ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=color, cmap=plt.cm.viridis)

# Customize the plot
ax.set_title('Swiss Roll Dataset')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Add a colorbar
plt.colorbar(scatter)

plt.show()

# %%
X_reduced = ParametricUMAP(device='cuda:3').fit_transform(X)
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 1/10, Loss: 0.0786
# Epoch 2/10, Loss: 0.0466
# Epoch 3/10, Loss: 0.0451
# Epoch 4/10, Loss: 0.0425
# Epoch 5/10, Loss: 0.0428
# Epoch 6/10, Loss: 0.0421
# Epoch 7/10, Loss: 0.0417
# Epoch 8/10, Loss: 0.0416
# Epoch 9/10, Loss: 0.0402
# Epoch 10/10, Loss: 0.0398

# %%
plt.figure(figsize=(10,8))
plt.scatter(X_reduced[:,0], 
           X_reduced[:,1],
           c=color,
           cmap='viridis')
plt.colorbar(label='Color Value')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('Reduced Coordinates with Color Mapping')
plt.show()
